# %%
import torch
ckpt = torch.load("/simurgh/u/alanqw/experiments/__train__age_regressor_for_evaluation_t1all_agebalanced_batch1_lr0.0001_datat1all_agebalanced_batch1_lr0.0001_seed23/checkpoints/epoch110_trained_model.pth.tar")

print(ckpt)
# Out:
# {'099_S_4498': 5,
#  '027_S_1081': 5,
#  '035_S_4784': 5,
#  '027_S_4926': 6,
#  '023_S_1190': 9,
#  '002_S_1280': 11,
#  '031_S_0554': 4,
#  '022_S_2167': 7,
#  '141_S_4907': 2,
#  '100_S_4556': 6,
#  '016_S_0538': 5,
#  '100_S_1286': 10,
#  '021_S_4335': 6,
#  '014_S_4576': 5,
#  '128_S_0245': 2,
#  '131_S_1389': 7,
#  '036_S_1023': 6,
#  '098_S_4003': 7,
#  '029_S_4307': 4,
#  '031_S_4032': 5,
#  '014_S_0557': 6,
#  '018_S_0633': 5,
#  '027_S_1082': 5,
#  '130_S_0423': 5,
#  '116_S_4010': 5,
#  '126_S_1077': 5,
#  '012_S_0689': 5,
#  '014_S_4079': 5,
#  '032_S_0187': 6,
#  '007_S_0698': 8,
#  '005_S_0221': 4,
#  '127_S_5028': 4,
#  '067_S_0038': 3,
#  '127_S_0260': 12,
#  '016_S_2031': 6,
#  '011_S_0023': 10,
#  '029_S_0845': 6,
#  '035_S_0292': 12,
#  '011_S_0010': 4,
#  '023_S_0081': 6,
#  '037_S_0588': 7,
#  '010_S_0067': 4,
#  '116_S_0361': 11,
#  '072_S_2026': 4,
#  '051_S_1131': 8,
#  '126_S_4514': 6,
#  '098_S_0269': 8,
#  '007_S_0344': 6,
#  '032_S_0214': 11,
# ...
